# %%
import pandas as pd

# %%
import numpy as np

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
chipo=pd.read_csv(url,sep='\t')

# %%
chipo.shape[0] # entries <= 4622 observations
# Out:
# 4622

# %%
df=pd.read_csv('C:\\Users\\kumar\\Desktop\\ipyhton\\mtcars.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-14-4fd53f6474c3> in <module>
# ----> 1 df=pd.read_csv('C:\\Users\\kumar\\Desktop\\ipyhton\\mtcars.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
Step 6. What is the number of columns in the dataset?
# Out:
# Object `dataset` not found.

# %%
Step 6. What is the number of columns in the dataset

# %%
chipo.shape[1] ##What is the number of columns in the dataset?
# Out:
# 5

# %%
chipo.columns##Print the name of all the columns.
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.index           #####How is the dataset indexed?
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
c = chipo.groupby('item_name')

# %%
c
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     37550        40
# [Lemonade]                                             31892        36
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice,...     24432        36
# [Coca Cola]                                            19282        32
# [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream,...     29614        30
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]      27583        30
# [Fresh Tomato Salsa, [Rice, Cheese, Lettuce]]          23326        26
# ...

# %%
c=c.sum()

# %%
c=c.sort_values(['quantity'],ascending=False)  Which was the most-ordered item?
# Out:
# Object `item` not found.

# %%
c=c.sort_values(['quantity'],ascending=False)  Which was the most-ordered item

# %%
c.head(1)
# Out:
#                    order_id  quantity
# item_name
# 6 Pack Soft Drink     52322        55

# %%
c = chipo.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending=False)    ###What was the most ordered item in the choice_description column?
c.head(1)
# Out:
#                     order_id  quantity
# choice_description
# [Diet Coke]           123455       159

# %%
total_items_orders = chipo.quantity.sum()   ####How many items were orderd in total?
total_items_orders
# Out:
# 4972

# %%
chipo.item_price.dtype   ####   Step 13. Turn the item price into a float
                        ###     Step 13.a. Check the item price type
# Out:
# dtype('O')

# %%
dollarizer = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(dollarizer)

# %%
import pandas as pd

# %%
import numpy as np

# %%
choose=pd.read_csv('C:\\Users\\kumar\\Desktop\\mtcars.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-19-f88447f79293> in <module>
# ----> 1 choose=pd.read_csv('C:\\Users\\kumar\\Desktop\\mtcars.xlsx')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
choose.head(10)
# Out:
#               shrimp       almonds     avocado    vegetables mix green grapes  \
# 0            burgers     meatballs        eggs               NaN          NaN
# 1            chutney           NaN         NaN               NaN          NaN
# 2             turkey       avocado         NaN               NaN          NaN
# 3      mineral water          milk  energy bar  whole wheat rice    green tea
# 4     low fat yogurt           NaN         NaN               NaN          NaN
# 5  whole wheat pasta  french fries         NaN               NaN          NaN
# 6               soup   light cream     shallot               NaN          NaN
# 7  frozen vegetables     spaghetti   green tea               NaN          NaN
# 8       french fries           NaN         NaN               NaN          NaN
# 9               eggs      pet food         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# ...

# %%
mkk = pd.read_csv('C:\\Users\\kumar\\Desktop\\ipyhton\\mtcars.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-34-83b1c7c92fc1> in <module>
# ----> 1 mkk = pd.read_csv('C:\\Users\\kumar\\Desktop\\ipyhton\\mtcars.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
